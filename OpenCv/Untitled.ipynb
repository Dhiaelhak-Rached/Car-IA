# %%
import cv2
import os
from matplotlib import pyplot as plt
from tensorflow.keras.models import load_model
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
new_model = load_model('/home/dhia/Desktop/OpenCv/final.h5')

# %%
cap=cv2.VideoCapture('/home/dhia/Desktop/OpenCv/Data/awakedhia.mp4')

# %%
ret, frame=cap.read()

# %%
frame.shape
# Out:
# (656, 304, 3)

# %%
plt.imshow(frame)
plt.show()

# %%
frame
# Out:
# array([[[171, 163, 158],
#         [171, 163, 158],
#         [171, 163, 158],
#         ...,
#         [154, 137, 138],
#         [154, 137, 138],
#         [154, 137, 138]],
#
#        [[171, 163, 158],
#         [171, 163, 158],
#         [171, 163, 158],
#         ...,
#         [159, 142, 143],
#         [159, 142, 143],
#         [159, 142, 143]],
#
#        [[171, 163, 158],
#         [171, 163, 158],
#         [171, 163, 158],
#         ...,
#         [162, 150, 150],
#         [162, 150, 150],
#         [162, 150, 150]],
#
#        ...,
#
#        [[  5,  15,  19],
#         [  5,  15,  19],
#         [  5,  15,  19],
#         ...,
#         [ 63,  83, 124],
#         [ 63,  83, 124],
#         [ 63,  83, 124]],
#
#        [[  5,  15,  19],
#         [  5,  15,  19],
#         [  5,  15,  19],
#         ...,
#         [ 41,  61, 102],
#         [ 41,  61, 102],
#         [ 41,  61, 102]],
#
#        [[  5,  15,  19],
#         [  5,  15,  19],
#         [  5,  15,  19],
# ...

# %%
cap.read()
# Out:
# (True,
#  array([[[171, 163, 158],
#          [171, 163, 158],
#          [171, 163, 158],
#          ...,
#          [156, 136, 138],
#          [156, 136, 138],
#          [156, 136, 138]],
#
#         [[171, 163, 158],
#          [171, 163, 158],
#          [171, 163, 158],
#          ...,
#          [160, 140, 142],
#          [160, 140, 142],
#          [160, 140, 142]],
#
#         [[171, 163, 158],
#          [171, 163, 158],
#          [171, 163, 158],
#          ...,
#          [162, 147, 148],
#          [162, 147, 148],
#          [162, 147, 148]],
#
#         ...,
#
#         [[  6,  16,  20],
#          [  6,  16,  20],
#          [  5,  15,  19],
#          ...,
#          [ 60,  80, 121],
#          [ 60,  80, 121],
#          [ 60,  80, 121]],
#
#         [[  6,  16,  20],
#          [  6,  16,  20],
#          [  5,  15,  19],
#          ...,
#          [ 64,  84, 125],
#          [ 64,  84, 125],
#          [ 64,  84, 125]],
#
#         [[  6,  16,  20],
# ...

# %%
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# 656.0

# %%
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# 304.0

# %%
cap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 1024.0

# %%
cap.get(cv2.CAP_PROP_FPS)
# Out:
# 30.0

# %%
cap=cv2.VideoCapture('/home/dhia/Desktop/OpenCv/Data/asleepdh.mp4')

for i in range(0,int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    ret, frame=cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    resize = tf.image.resize(frame, (256,256))
    print(new_model.predict(np.expand_dims(resize/255, 0)))
    if cv2.waitKey(10) & 0xFF == ord('t'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [[1.2518082e-10]]
# 1/1 [==============================] - 0s 12ms/step
# [[4.08043e-11]]
# 1/1 [==============================] - 0s 12ms/step
# [[7.403319e-11]]
# 1/1 [==============================] - 0s 13ms/step
# [[3.7587977e-10]]
# 1/1 [==============================] - 0s 12ms/step
# [[3.612792e-07]]
# 1/1 [==============================] - 0s 13ms/step
# [[5.81999e-05]]
# 1/1 [==============================] - 0s 14ms/step
# [[0.00017315]]
# 1/1 [==============================] - 0s 16ms/step
# [[0.00068642]]
# 1/1 [==============================] - 0s 14ms/step
# [[0.00208732]]
# 1/1 [==============================] - 0s 15ms/step
# [[0.0057244]]
# 1/1 [==============================] - 0s 14ms/step
# [[0.081234]]
# 1/1 [==============================] - 0s 14ms/step
# [[0.28434524]]
# 1/1 [==============================] - 0s 13ms/step
# [[0.5379548]]
# 1/1 [==============================] - 0s 13ms/step
# ...

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','coders.mp4'))

# Properties
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = cap.get(cv2.CAP_PROP_FPS)
# Video Writer 
video_writer = cv2.VideoWriter(os.path.join('data','output','output.avi'), cv2.VideoWriter_fourcc('P','I','M','1'), fps, (width, height), isColor=False) 
                                                                                        
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    # Write out frame 
    video_writer.write(gray)
    
    # Breaking out of the loop
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Release video writer
video_writer.release()
# Out:
# [ERROR:0@886.099] global /io/opencv/modules/videoio/src/cap.cpp (595) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.6.0) /io/opencv/modules/videoio/src/cap_images.cpp:253: error: (-5:Bad argument) CAP_IMAGES: can't find starting number (in the name of file): data/output/output.avi in function 'icvExtractPattern'
